# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# %%
dataset = pd.read_csv("E:\CODE\py-first-practice-data-analytics-01\dataset\Retail_sale.csv")

# %%
dataset.head(15)
# Out:
#     YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0   2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1   2020      1                          PWSWN INC    100024
# 2   2020      1            RELIABLE CHURCHILL LLLP      1001
# 3   2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4   2020      1               DIONYSOS IMPORTS INC    100293
# 5   2020      1            KYSELA PERE ET FILS LTD    100641
# 6   2020      1           SANTA MARGHERITA USA INC    100749
# 7   2020      1   BROWN-FORMAN BEVERAGES WORLDWIDE      1008
# 8   2020      1                 JIM BEAM BRANDS CO     10103
# 9   2020      1          INTERNATIONAL CELLARS LLC    101117
# 10  2020      1       HEAVEN HILL DISTILLERIES INC     10120
# 11  2020      1              BACCHUS IMPORTERS LTD     10123
# 12  2020      1              BACCHUS IMPORTERS LTD     10124
# 13  2020      1              BACCHUS IMPORTERS LTD     10125
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              30000 non-null  int64
#  1   MONTH             30000 non-null  int64
#  2   SUPPLIER          29967 non-null  object
#  3   ITEM CODE         30000 non-null  object
#  4   ITEM DESCRIPTION  30000 non-null  object
#  5   ITEM TYPE         30000 non-null  object
#  6   RETAIL SALES      29999 non-null  float64
#  7   RETAIL TRANSFERS  30000 non-null  float64
#  8   WAREHOUSE SALES   30000 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.1+ MB

# %%
dataset.describe()
# Out:
#           YEAR         MONTH  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# count  30000.0  30000.000000  29999.000000      30000.000000     30000.000000
# mean    2020.0      3.911467      6.939796          6.594058        27.431031
# std        0.0      2.836788     33.081054         27.879428       272.166085
# min     2020.0      1.000000     -0.420000         -6.000000     -3999.000000
# 25%     2020.0      1.000000      0.000000          0.000000         0.000000
# 50%     2020.0      3.000000      0.160000          0.000000         1.000000
# 75%     2020.0      7.000000      2.920000          3.000000         6.000000
# max     2020.0      9.000000   2739.000000       1507.000000     18317.000000

# %%
dataset.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# SUPPLIER            33
# ITEM CODE            0
# ITEM DESCRIPTION     0
# ITEM TYPE            0
# RETAIL SALES         1
# RETAIL TRANSFERS     0
# WAREHOUSE SALES      0
# dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.histplot(dataset['MONTH'] , bins=50 )
plt.title('Distribution of Sales Revenue')
plt.xlabel('WAREHOUSE SALES')
plt.ylabel('Frequency')
plt.show()

# %%
plt.style.use('_mpl-gallery')

# make data
# x = np.linspace(0, 10, 100)
# y = 4 + 1 * np.sin(2 * x)
# x2 = np.linspace(0, 10, 25)
# y2 = 4 + 1 * np.sin(2 * x2)
x = dataset['MONTH']
y = dataset['RETAIL TRANSFERS']
# plot
fig, ax = plt.subplots()

# ax.plot(x2, y2 + 2.5, 'x', markeredgewidth=2)
ax.plot(x, y,)
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Monthly Values')

# Customize the plot
plt.xlabel('Month')               # x-axis label
plt.ylabel('Value')               # y-axis label
plt.title('Monthly Values Plot')  # Plot title
plt.xticks(rotation=45)           # Rotate the month labels for better visibility
plt.grid(True)                    # Show grid
plt.legend()  
# ax.plot(x2, y2 - 2.5, 'o-', linewidth=2)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#      ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
